# %% [markdown]
# # CNN Version 3 - CIFAR-10 dataset

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

# %%
gpus = tf.config.list_physical_devices('GPU')
if len(gpus) > 0:
    print(f"GPU's available: {gpus}")
    print("Using first GPU")
    try:
      # Use first GPU
      tf.config.set_visible_devices(gpus[0], 'GPU')
      logical_devices = tf.config.list_logical_devices('GPU')
      assert len(logical_devices) == 1
    except Exception as e:
      # Invalid device or cannot modify virtual devices once initialized.
      print(f"Error while loading GPU: {e}")
else:
    print("GPU's not available")
# Out:
# GPU's available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Using first GPU

# %% [markdown]
# ## Load Dataset

# %%
# Use the CIFAR-10 dataset from keras for easier retrieval
# (However we are going to use the raw CIFAR-10 dataset and do the splitting ourselves)
(X_train_keras, y_train_keras), (X_test_keras, y_test_keras) = cifar10.load_data()
X = np.concatenate((X_train_keras, X_test_keras), axis=0)
y = np.concatenate((y_train_keras, y_test_keras), axis=0)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# ## Data Preprocessing

# %%
X_scaled = X / 255.0
y_cat = to_categorical(y, 10)

# %% [markdown]
# ## Training-Validation-Test Split

# %%
# 80-10-10 train-val-test split (48000, 6000, 6000)
X_train, X_remain, y_train, y_remain = train_test_split(X_scaled, y_cat, test_size=0.2, random_state=42, stratify=y_cat)
X_val, X_test, y_val, y_test = train_test_split(X_remain, y_remain, test_size=0.5, random_state=42, stratify=y_remain)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (48000, 32, 32, 3)
# y_train shape: (48000, 10)
# X_val shape: (6000, 32, 32, 3)
# y_val shape: (6000, 10)
# X_test shape: (6000, 32, 32, 3)
# y_test shape: (6000, 10)

# %% [markdown]
# ## Model Architecture

# %%
model_name = "cnn_version_3"
model = Sequential()

# First block of Conv2D layers
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.3))

# Second block of Conv2D layers
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.3))

# Third block of Conv2D layers (to increase depth)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.4))

# Global Average Pooling to reduce number of parameters
model.add(GlobalAveragePooling2D())

# Fully connected layer with reduced dropout
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 324,394 (1.24 MB)
#  Trainable params: 323,498 (1.23 MB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ## Train Model

# %%
loss = 'categorical_crossentropy'
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
metrics = ['accuracy']

model.compile(loss = loss, optimizer = opt, metrics = metrics)

# %% [markdown]
# ### Learning Rate Scheduler and Early Stopping

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

# %%
r = model.fit(X_train, y_train, batch_size = 64 , epochs = 50, validation_data = (X_val, y_val), callbacks=[early_stopping, lr_scheduler],)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.3653 - loss: 1.7424 - val_accuracy: 0.5643 - val_loss: 1.2082 - learning_rate: 0.0010
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.6050 - loss: 1.1151 - val_accuracy: 0.5748 - val_loss: 1.3307 - learning_rate: 0.0010
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.6792 - loss: 0.9188 - val_accuracy: 0.6822 - val_loss: 0.8770 - learning_rate: 0.0010
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7208 - loss: 0.7976 - val_accuracy: 0.7163 - val_loss: 0.8366 - learning_rate: 0.0010
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7584 - loss: 0.7068 - val_accuracy: 0.7668 - val_loss: 0.6773 - learning_rate: 0.0010
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7706 - loss: 0.6660 - val_accuracy: 0.7840 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7904 - loss: 0.6168 - val_accuracy: 0.8003 - val_loss: 0.5811 - learning_rate: 0.0010
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8017 - loss: 0.5746 - val_accuracy: 0.7938 - val_loss: 0.6143 - learning_rate: 0.0010
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8099 - loss: 0.5477 - val_accuracy: 0.7982 - val_loss: 0.5943 - learning_rate: 0.0010
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8229 - loss: 0.5219 - val_accuracy: 0.8107 - val_loss: 0.5549 - learning_rate: 0.0010
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8275 - loss: 0.5027 - val_accuracy: 0.8063 - val_loss: 0.5919 - learning_rate: 0.0010
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8322 - loss: 0.4880 - val_accuracy: 0.8370 - val_loss: 0.4896 - learning_rate: 0.0010
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8388 - loss: 0.4686 - val_accuracy: 0.8217 - val_loss: 0.5382 - learning_rate: 0.0010
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8475 - loss: 0.4447 - val_accuracy: 0.8082 - val_loss: 0.5740 - learning_rate: 0.0010
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8499 - loss: 0.4346 - val_accuracy: 0.8440 - val_loss: 0.4670 - learning_rate: 0.0010
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8559 - loss: 0.4224 - val_accuracy: 0.8297 - val_loss: 0.5084 - learning_rate: 0.0010
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8592 - loss: 0.4086 - val_accuracy: 0.8260 - val_loss: 0.5228 - learning_rate: 0.0010
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8590 - loss: 0.4037 - val_accuracy: 0.8453 - val_loss: 0.4488 - learning_rate: 0.0010
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8640 - loss: 0.3972 - val_accuracy: 0.8383 - val_loss: 0.4983 - learning_rate: 0.0010
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8722 - loss: 0.3763 - val_accuracy: 0.8345 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8688 - loss: 0.3718 - val_accuracy: 0.8498 - val_loss: 0.4412 - learning_rate: 0.0010
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8727 - loss: 0.3624 - val_accuracy: 0.8457 - val_loss: 0.4601 - learning_rate: 0.0010
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8742 - loss: 0.3589 - val_accuracy: 0.8513 - val_loss: 0.4477 - learning_rate: 0.0010
# Epoch 24/50
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8780 - loss: 0.3515
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8780 - loss: 0.3515 - val_accuracy: 0.8515 - val_loss: 0.4750 - learning_rate: 0.0010
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8914 - loss: 0.3135 - val_accuracy: 0.8670 - val_loss: 0.4039 - learning_rate: 5.0000e-04
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8961 - loss: 0.2994 - val_accuracy: 0.8710 - val_loss: 0.4256 - learning_rate: 5.0000e-04
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8992 - loss: 0.2865 - val_accuracy: 0.8708 - val_loss: 0.4024 - learning_rate: 5.0000e-04
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9031 - loss: 0.2720 - val_accuracy: 0.8723 - val_loss: 0.4007 - learning_rate: 5.0000e-04
# Epoch 29/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9068 - loss: 0.2694 - val_accuracy: 0.8757 - val_loss: 0.4005 - learning_rate: 5.0000e-04
# Epoch 30/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9070 - loss: 0.2733 - val_accuracy: 0.8717 - val_loss: 0.4210 - learning_rate: 5.0000e-04
# Epoch 31/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9074 - loss: 0.2625 - val_accuracy: 0.8792 - val_loss: 0.3996 - learning_rate: 5.0000e-04
# Epoch 32/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9083 - loss: 0.2601 - val_accuracy: 0.8757 - val_loss: 0.4036 - learning_rate: 5.0000e-04
# Epoch 33/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9113 - loss: 0.2529 - val_accuracy: 0.8792 - val_loss: 0.4106 - learning_rate: 5.0000e-04
# Epoch 34/50
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9143 - loss: 0.2434
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9143 - loss: 0.2434 - val_accuracy: 0.8747 - val_loss: 0.4116 - learning_rate: 5.0000e-04
# Epoch 35/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9217 - loss: 0.2250 - val_accuracy: 0.8800 - val_loss: 0.4017 - learning_rate: 2.5000e-04
# Epoch 36/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9198 - loss: 0.2244 - val_accuracy: 0.8830 - val_loss: 0.3944 - learning_rate: 2.5000e-04
# Epoch 37/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9247 - loss: 0.2140 - val_accuracy: 0.8835 - val_loss: 0.3965 - learning_rate: 2.5000e-04
# Epoch 38/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9249 - loss: 0.2143 - val_accuracy: 0.8820 - val_loss: 0.3970 - learning_rate: 2.5000e-04
# Epoch 39/50
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9254 - loss: 0.2139
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9253 - loss: 0.2138 - val_accuracy: 0.8822 - val_loss: 0.4153 - learning_rate: 2.5000e-04
# Epoch 40/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9274 - loss: 0.2043 - val_accuracy: 0.8840 - val_loss: 0.3951 - learning_rate: 1.2500e-04
# Epoch 41/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9288 - loss: 0.2025 - val_accuracy: 0.8845 - val_loss: 0.3934 - learning_rate: 1.2500e-04
# Epoch 42/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9265 - loss: 0.2046 - val_accuracy: 0.8868 - val_loss: 0.3902 - learning_rate: 1.2500e-04
# Epoch 43/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9293 - loss: 0.2032 - val_accuracy: 0.8880 - val_loss: 0.3940 - learning_rate: 1.2500e-04
# Epoch 44/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9336 - loss: 0.1892 - val_accuracy: 0.8883 - val_loss: 0.3892 - learning_rate: 1.2500e-04
# Epoch 45/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9355 - loss: 0.1898 - val_accuracy: 0.8885 - val_loss: 0.3909 - learning_rate: 1.2500e-04
# Epoch 46/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9308 - loss: 0.1982 - val_accuracy: 0.8865 - val_loss: 0.3947 - learning_rate: 1.2500e-04
# Epoch 47/50
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9338 - loss: 0.1905
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9338 - loss: 0.1905 - val_accuracy: 0.8868 - val_loss: 0.3981 - learning_rate: 1.2500e-04
# Epoch 48/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9329 - loss: 0.1859 - val_accuracy: 0.8865 - val_loss: 0.3954 - learning_rate: 6.2500e-05
# Epoch 49/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9342 - loss: 0.1871 - val_accuracy: 0.8870 - val_loss: 0.3951 - learning_rate: 6.2500e-05
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 44.

# %% [markdown]
# ## Save Model

# %%
model.save(f'{model_name}.h5')

# %% [markdown]
# ## Model Performance

# %% [markdown]
# ### Acuraccy and Loss Evaluation

# %%
plt.figure(figsize=(12, 16))

plt.subplot(4, 2, 1)
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='val_Loss')
plt.title('Loss Function Evolution')
plt.legend()

plt.subplot(4, 2, 2)
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.title('Accuracy Function Evolution')
plt.legend()

# %% [markdown]
# ### Accuracy with the Testing Data

# %%
train_evaluation = model.evaluate(X_train, y_train, return_dict=True)
print(f'Training Accuracy : {train_evaluation["accuracy"] * 100:.2f}%')
val_evaluation = model.evaluate(X_val, y_val, return_dict=True)
print(f'Validation Accuracy : {val_evaluation["accuracy"] * 100:.2f}%')
test_evaluation = model.evaluate(X_test, y_test, return_dict=True)
print(f'Test Accuracy : {test_evaluation["accuracy"] * 100:.2f}%')
# Out:
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9872 - loss: 0.0445
# Training Accuracy : 98.74%
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8827 - loss: 0.3933
# Validation Accuracy : 88.83%
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8821 - loss: 0.4150
# Test Accuracy : 88.03%

# %% [markdown]
# ### Confusion Matrix

# %%
class_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
y_predictions = model.predict(X_test)
y_pred = np.argmax(y_predictions, axis=1)
y_test_true_labels = np.argmax(y_test, axis=1)
sns.heatmap(
    confusion_matrix(y_test_true_labels, y_pred), annot=True, fmt='d', cmap='Blues',
    xticklabels=class_labels, yticklabels=class_labels)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# <Axes: >

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test_true_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       600
#            1       0.94      0.95      0.95       600
#            2       0.85      0.82      0.84       600
#            3       0.79      0.74      0.76       600
#            4       0.83      0.88      0.86       600
#            5       0.80      0.78      0.79       600
#            6       0.88      0.92      0.90       600
#            7       0.92      0.92      0.92       600
#            8       0.94      0.94      0.94       600
#            9       0.94      0.94      0.94       600
#
#     accuracy                           0.88      6000
#    macro avg       0.88      0.88      0.88      6000
# weighted avg       0.88      0.88      0.88      6000

# %% [markdown]
# ### ROC Curve and AUC for each class

# %%
n_classes = len(class_labels)
class_colors = ['red', 'blue', 'orange', 'purple', 'magenta', 'gold', 'brown', 'pink', 'teal', 'indigo']
fpr = {}
tpr = {}
roc_auc = {}

fig, axes = plt.subplots(5, 2, figsize=(20, 18))
axes = axes.ravel()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    axes[i].plot(fpr[i], tpr[i], label=f'ROC curve (AUC = {roc_auc[i]:.2f})', color=class_colors[i])
    axes[i].plot([0, 1], [0, 1], 'k--', label='Random Guess')
    axes[i].set_title(f'ROC curce and AUC - Class: {class_labels[i]}')
    axes[i].set_xlabel('False Positive Rate')
    axes[i].set_ylabel('True Positive Rate')
    axes[i].legend(loc='lower right')
    axes[i].grid()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
